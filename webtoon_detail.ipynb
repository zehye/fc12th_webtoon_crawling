# %%
from bs4 import BeautifulSoup
html = open('episode_list.html', 'rt').read()
soup = BeautifulSoup(html)
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <title>유미의 세포들 :: 네이버 만화</title>
# <meta content="유미의 세포들 - 437화 당신이 받고 있는 시그널 5" property="og:title"/>
# <meta content="https://shared-comic.pstatic.net/thumb/webtoon/651673/440/thumbnail_600x315_0852f5d0-0783-4e6b-9582-ce415fa61625.jpg" property="og:image"/>
# <meta content="437화 당신이 받고 있는 시그널 5" property="og:description"/>
# <meta content="https://comic.naver.com/webtoon/detail.nhn?titleId=651673&amp;no=440&amp;weekday=wed" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 웹툰" property="og:article:author"/>
# <meta content="https://comic.naver.com" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
# 		document.domain = "naver.com";
# 	</script>
# ...

# %%
for div_detail in soup.select('div.detail'):
#     print(div_detail)
    h2 = div_detail.select_one('h2').get_text(strip=True)
    print(h2)
    p_txt = div_detail.select_one('p.txt').get_text(strip=True)
    print(p_txt)
    p_detail_info = div_detail.select_one('p.detail_info').get_text(strip=True)
    print(p_detail_info)
# Out:
# 유미의 세포들컷툰이동건
# 유미는 지금 무슨 생각을 하고 있을까?그녀의 머릿속에서 바쁘게 움직이는 세포들 이야기!
# 에피소드, 일상, 개그, 로맨스12세 이용가

# %%
div_detail = soup.select_one('.detail h2')
h2 = div_detail.contents[0]
span1 = div_detail.contents[1].get_text(strip=True)
span2 = div_detail.contents[2].get_text('\n', strip=True)
print(h2)
# print(span1)
print(span2)
for p in soup.select('.detail'):
    p_txt = p.select_one('p.txt').get_text(strip=True)
    print(p_txt)
    p_detail_info = p.select_one('p.detail_info').get_text(strip=True)
    print(p_detail_info)
# Out:
# 유미의 세포들
# 이동건
# 유미는 지금 무슨 생각을 하고 있을까?그녀의 머릿속에서 바쁘게 움직이는 세포들 이야기!
# 에피소드, 일상, 개그, 로맨스12세 이용가

# %%
div_comicinfo = soup.select_one('.comicinfo')
div_detail = div_comicinfo.select_one('.detail')
div_detail
# Out:
# <div class="detail">
# <h2>유미의 세포들<span class="ico_cut">컷툰</span><span class="wrt_nm">
#                 	 이동건</span>
# </h2>
# <p class="txt">유미는 지금 무슨 생각을 하고 있을까?<br/>그녀의 머릿속에서 바쁘게 움직이는 세포들 이야기!</p>
# <p class="detail_info"><span class="genre">에피소드, 일상, 개그, 로맨스</span><span class="age">12세 이용가</span></p>
# <ul class="btn_group">
# <li>
# <a class="book_maker" href="javascript:actionRunner.addFavoriteWebtoon('651673');" onclick="nclk_v2(event,'inf.zzim');" title="관심웹툰">
# <span>관심웹툰</span>
# </a>
# </li>
# <li><a class="first" href="#" onclick="nclk_v2(event,'inf.first');return checkServiceCode('subTitle','S00','1');" title="첫회보기"><span>첫회보기</span></a></li>
# <li><a class="lst" href="/webtoon/list.nhn?titleId=651673&amp;weekday=wed" onclick="nclk_v2(event,'inf.list')" title="목록보기"><span>목록보기</span></a></li>
# ...

# %%
h2 = div_detail.select_one('h2').contents[0]
h2
# Out:
# '유미의 세포들'

# %%
author= div_detail.select_one('span.wrt_nm').get_text(strip=True)
author
# Out:
# '이동건'

# %%
description = div_detail.select_one('p.txt').get_text('\n', strip=True)
print(description)
# Out:
# 유미는 지금 무슨 생각을 하고 있을까?
# 그녀의 머릿속에서 바쁘게 움직이는 세포들 이야기!

# %%
div_detail_info = div_detail.select_one('p.detail_info')
genre = div_detail_info.select_one('span.genre').get_text(strip=True)
age = div_detail_info.select_one('span.age').get_text(strip=True)
print(genre)
print(age)
# Out:
# 에피소드, 일상, 개그, 로맨스
# 12세 이용가

# %%
def get_webtoon_detail():
    html = open('episode_list.html', 'rt').read()
    soup = BeautifulSoup(html)
    
    div_comicinfo = soup.select_one('.comicinfo')
    div_detail = div_comicinfo.select_one('.detail')
    
    title = div_detail.select_one('h2').contents[0]
    description = div_detail.select_one('p.txt').get_text('\n', strip=True)
    author= div_detail.select_one('span.wrt_nm').get_text(strip=True)
    
    div_detail_info = div_detail.select_one('p.detail_info')
    genre = div_detail_info.select_one('span.genre').get_text(strip=True)
    age = div_detail_info.select_one('span.age').get_text(strip=True)
    
    cur_dict = {
        'title': title,
        'description': description,
        'author': author,
        'genre': genre,
        'age': age,
    }
    
    return cur_dict

# %%
get_webtoon_detail()
# Out:
# {'title': '유미의 세포들',
#  'description': '유미는 지금 무슨 생각을 하고 있을까?\n그녀의 머릿속에서 바쁘게 움직이는 세포들 이야기!',
#  'author': '이동건',
#  'genre': '에피소드, 일상, 개그, 로맨스',
#  'age': '12세 이용가'}

# %%
webtoon_dict = {}

def get_webtoon_detail2():
    html = open('episode_list.html', 'rt').read()
    soup = BeautifulSoup(html)
    
    div_comicinfo = soup.select_one('.comicinfo')
    div_detail = div_comicinfo.select_one('.detail')
    
    title = div_detail.select_one('h2').contents[0]
    description = div_detail.select_one('p.txt').get_text('\n', strip=True)
    author= div_detail.select_one('span.wrt_nm').get_text(strip=True)
    
    div_detail_info = div_detail.select_one('p.detail_info')
    genre = div_detail_info.select_one('span.genre').get_text(strip=True)
    age = div_detail_info.select_one('span.age').get_text(strip=True)
    
    webtoon_dict['title'] = title
    webtoon_dict['description'] = description
    webtoon_dict['author'] = author
    webtoon_dict['genre'] = genre.split(', ')
    webtoon_dict['age'] = age
    
    return webtoon_dict

# %%
get_webtoon_detail2()
# Out:
# {'title': '유미의 세포들',
#  'description': '유미는 지금 무슨 생각을 하고 있을까?\n그녀의 머릿속에서 바쁘게 움직이는 세포들 이야기!',
#  'author': '이동건',
#  'genre': ['에피소드', '일상', '개그', '로맨스'],
#  'age': '12세 이용가'}
